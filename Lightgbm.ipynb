# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import lightgbm as lgb
from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import seaborn as sns
import warnings

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
pd.set_option('max_columns', 100)
pd.set_option("display.precision", 4)
warnings.simplefilter('ignore')

# %%
#학습데이터 로드
#이전 판다스 실습에서 생성한 feature.csv를 사용한다.
data_dir = Path('../data/dacon-dku')
feature_dir = Path('../build/feature')
sub_dir = Path('../build/sub')

trn_file = data_dir / 'train.csv'
tst_file = data_dir / 'test.csv'
sample_file = data_dir / 'sample_submission.csv'

target_col = 'class'
seed = 42

# %%
algo_name = 'lgb'
feature_name = 'feature'
model_name = f'{algo_name}_{feature_name}'

feature_file = feature_dir / f'{feature_name}.csv'
sub_file = sub_dir / f'{model_name}.csv'

# %%
df = pd.read_csv(feature_file, index_col=0)
print(df.shape)
df.head()
# Out:
# (400000, 20)
#           z    redshift  dered_u  dered_g  dered_r  dered_i  dered_z  \
# id
# 0   16.9396 -8.1086e-05  23.1243  20.2578  18.9551  17.6321  16.9089
# 1   13.1689  4.5061e-03  14.9664  14.0045  13.4114  13.2363  13.1347
# 2   15.3500  4.7198e-04  16.6076  15.6866  15.4400  15.3217  15.2961
# 3   19.6346  5.8143e-06  25.3536  20.9947  20.0873  19.7947  19.5552
# 4   17.9826 -3.3247e-05  23.7714  20.4338  18.8630  18.1903  17.8759
#
#     nObserve  airmass_u  class  d_dered_u  d_dered_g  d_dered_r  d_dered_i  \
# id
# 0     0.8639     1.1898    0.0    -0.1397    -0.0790    -0.0544    -0.0403
# 1     0.4230     1.2533    1.0    -0.0857    -0.0574    -0.0410    -0.0322
# 2     0.5546     1.0225    0.0    -0.1787    -0.1388    -0.0963    -0.0718
# 3     0.6725     1.2054    0.0    -0.3070    -0.1941    -0.1339    -0.1003
# 4     0.8293     1.1939    0.0    -0.6820    -0.2653    -0.1794    -0.1339
#
#     d_dered_z  d_dered_ig  d_dered_zg  d_dered_rz  d_dered_iz  d_obs_det
# id
# 0     -0.0307     -2.6257     -3.3488      2.0462      0.7232   -17.1361
# 1     -0.0343     -0.7683     -0.8698      0.2767      0.1016    -0.5770
# 2     -0.0540     -0.3649     -0.3905      0.1440      0.0257    -1.4454
# 3     -0.0795     -1.2000     -1.4395      0.5321      0.2395    -2.3275
# 4     -0.1067     -2.2436     -2.5579      0.9871      0.3144   -11.1707

# %%
y = df[target_col].values[:320000]
df.drop(target_col, axis=1, inplace=True)
trn = df.iloc[:320000]
tst = df.iloc[320000:]
feature_name = df.columns.tolist()
print(y.shape, trn.shape, tst.shape)
# Out:
# (320000,) (320000, 19) (80000, 19)

# %%
#학습/검증 데이터 구분
X_trn, X_val, y_trn, y_val = train_test_split(trn, y, test_size=.2, random_state=seed)
print(X_trn.shape, X_val.shape, y_trn.shape, y_val.shape)
# Out:
# (256000, 19) (64000, 19) (256000,) (64000,)

# %%
#LightGBM 모델 학습
clf = lgb.LGBMClassifier(objective='multiclass',
                         n_estimators=1000,
                         num_leaves=64,
                         learning_rate=0.1,
                         min_child_samples=10,
                         subsample=.5,
                         subsample_freq=1,
                         colsample_bytree=.8,
                         random_state=seed,
                         n_jobs=-1)
clf.fit(X_trn, y_trn,
        eval_set=[(X_val, y_val)],
        eval_metric='multiclass',
        early_stopping_rounds=10)
p_val = clf.predict(X_val)
p_tst = clf.predict(tst)
# Out:
# [1]	valid_0's multi_logloss: 0.860794
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.76194
# [3]	valid_0's multi_logloss: 0.67628
# [4]	valid_0's multi_logloss: 0.605734
# [5]	valid_0's multi_logloss: 0.548153
# [6]	valid_0's multi_logloss: 0.506566
# [7]	valid_0's multi_logloss: 0.469036
# [8]	valid_0's multi_logloss: 0.440956
# [9]	valid_0's multi_logloss: 0.413042
# [10]	valid_0's multi_logloss: 0.384326
# [11]	valid_0's multi_logloss: 0.360346
# [12]	valid_0's multi_logloss: 0.339849
# [13]	valid_0's multi_logloss: 0.321762
# [14]	valid_0's multi_logloss: 0.30492
# [15]	valid_0's multi_logloss: 0.290898
# [16]	valid_0's multi_logloss: 0.278547
# [17]	valid_0's multi_logloss: 0.268067
# [18]	valid_0's multi_logloss: 0.258264
# [19]	valid_0's multi_logloss: 0.249211
# [20]	valid_0's multi_logloss: 0.2424
# [21]	valid_0's multi_logloss: 0.235295
# [22]	valid_0's multi_logloss: 0.228946
# [23]	valid_0's multi_logloss: 0.223079
# [24]	valid_0's multi_logloss: 0.218902
# [25]	valid_0's multi_logloss: 0.214858
# [26]	valid_0's multi_logloss: 0.211451
# [27]	valid_0's multi_logloss: 0.207777
# [28]	valid_0's multi_logloss: 0.204096
# [29]	valid_0's multi_logloss: 0.200815
# [30]	valid_0's multi_logloss: 0.198189
# [31]	valid_0's multi_logloss: 0.195569
# [32]	valid_0's multi_logloss: 0.193564
# [33]	valid_0's multi_logloss: 0.191387
# [34]	valid_0's multi_logloss: 0.189344
# [35]	valid_0's multi_logloss: 0.187458
# [36]	valid_0's multi_logloss: 0.186116
# [37]	valid_0's multi_logloss: 0.18464
# [38]	valid_0's multi_logloss: 0.183249
# [39]	valid_0's multi_logloss: 0.182144
# [40]	valid_0's multi_logloss: 0.180901
# [41]	valid_0's multi_logloss: 0.179777
# [42]	valid_0's multi_logloss: 0.178895
# [43]	valid_0's multi_logloss: 0.177939
# [44]	valid_0's multi_logloss: 0.177101
# [45]	valid_0's multi_logloss: 0.176428
# [46]	valid_0's multi_logloss: 0.175734
# [47]	valid_0's multi_logloss: 0.175109
# [48]	valid_0's multi_logloss: 0.174554
# [49]	valid_0's multi_logloss: 0.174069
# [50]	valid_0's multi_logloss: 0.173608
# [51]	valid_0's multi_logloss: 0.173055
# [52]	valid_0's multi_logloss: 0.172672
# [53]	valid_0's multi_logloss: 0.172232
# [54]	valid_0's multi_logloss: 0.171938
# [55]	valid_0's multi_logloss: 0.171798
# [56]	valid_0's multi_logloss: 0.171519
# [57]	valid_0's multi_logloss: 0.171274
# [58]	valid_0's multi_logloss: 0.170896
# [59]	valid_0's multi_logloss: 0.170723
# [60]	valid_0's multi_logloss: 0.170535
# [61]	valid_0's multi_logloss: 0.170205
# [62]	valid_0's multi_logloss: 0.169993
# [63]	valid_0's multi_logloss: 0.169792
# [64]	valid_0's multi_logloss: 0.169546
# [65]	valid_0's multi_logloss: 0.169339
# [66]	valid_0's multi_logloss: 0.169552
# [67]	valid_0's multi_logloss: 0.169079
# [68]	valid_0's multi_logloss: 0.168891
# [69]	valid_0's multi_logloss: 0.16862
# [70]	valid_0's multi_logloss: 0.168415
# [71]	valid_0's multi_logloss: 0.16862
# [72]	valid_0's multi_logloss: 0.16844
# [73]	valid_0's multi_logloss: 0.16834
# [74]	valid_0's multi_logloss: 0.168201
# [75]	valid_0's multi_logloss: 0.168051
# [76]	valid_0's multi_logloss: 0.167895
# [77]	valid_0's multi_logloss: 0.167761
# [78]	valid_0's multi_logloss: 0.167692
# [79]	valid_0's multi_logloss: 0.167611
# [80]	valid_0's multi_logloss: 0.167533
# [81]	valid_0's multi_logloss: 0.167456
# [82]	valid_0's multi_logloss: 0.167383
# [83]	valid_0's multi_logloss: 0.167248
# [84]	valid_0's multi_logloss: 0.167151
# [85]	valid_0's multi_logloss: 0.167098
# [86]	valid_0's multi_logloss: 0.166999
# [87]	valid_0's multi_logloss: 0.166902
# [88]	valid_0's multi_logloss: 0.166827
# [89]	valid_0's multi_logloss: 0.166786
# [90]	valid_0's multi_logloss: 0.167089
# [91]	valid_0's multi_logloss: 0.166795
# [92]	valid_0's multi_logloss: 0.166637
# [93]	valid_0's multi_logloss: 0.16655
# [94]	valid_0's multi_logloss: 0.166541
# [95]	valid_0's multi_logloss: 0.16648
# [96]	valid_0's multi_logloss: 0.166388
# [97]	valid_0's multi_logloss: 0.166308
# [98]	valid_0's multi_logloss: 0.166303
# [99]	valid_0's multi_logloss: 0.166189
# [100]	valid_0's multi_logloss: 0.166184
# [101]	valid_0's multi_logloss: 0.166107
# [102]	valid_0's multi_logloss: 0.166036
# [103]	valid_0's multi_logloss: 0.165948
# [104]	valid_0's multi_logloss: 0.165876
# [105]	valid_0's multi_logloss: 0.165828
# [106]	valid_0's multi_logloss: 0.165827
# [107]	valid_0's multi_logloss: 0.16579
# [108]	valid_0's multi_logloss: 0.16582
# [109]	valid_0's multi_logloss: 0.16572
# [110]	valid_0's multi_logloss: 0.165663
# [111]	valid_0's multi_logloss: 0.165615
# [112]	valid_0's multi_logloss: 0.165604
# [113]	valid_0's multi_logloss: 0.165535
# [114]	valid_0's multi_logloss: 0.165501
# [115]	valid_0's multi_logloss: 0.165423
# [116]	valid_0's multi_logloss: 0.165425
# [117]	valid_0's multi_logloss: 0.165422
# [118]	valid_0's multi_logloss: 0.165404
# [119]	valid_0's multi_logloss: 0.165392
# [120]	valid_0's multi_logloss: 0.165362
# [121]	valid_0's multi_logloss: 0.165318
# [122]	valid_0's multi_logloss: 0.165313
# [123]	valid_0's multi_logloss: 0.165224
# [124]	valid_0's multi_logloss: 0.165251
# [125]	valid_0's multi_logloss: 0.165227
# [126]	valid_0's multi_logloss: 0.165224
# [127]	valid_0's multi_logloss: 0.16522
# [128]	valid_0's multi_logloss: 0.165248
# [129]	valid_0's multi_logloss: 0.165231
# [130]	valid_0's multi_logloss: 0.165213
# [131]	valid_0's multi_logloss: 0.165219
# [132]	valid_0's multi_logloss: 0.16524
# [133]	valid_0's multi_logloss: 0.165175
# [134]	valid_0's multi_logloss: 0.165188
# [135]	valid_0's multi_logloss: 0.165185
# [136]	valid_0's multi_logloss: 0.165197
# [137]	valid_0's multi_logloss: 0.165175
# [138]	valid_0's multi_logloss: 0.16524
# [139]	valid_0's multi_logloss: 0.165252
# [140]	valid_0's multi_logloss: 0.165227
# [141]	valid_0's multi_logloss: 0.165267
# [142]	valid_0's multi_logloss: 0.165255
# [143]	valid_0's multi_logloss: 0.165231
# Early stopping, best iteration is:
# [133]	valid_0's multi_logloss: 0.165175

# %%
print(f'{accuracy_score(y_val, p_val) * 100:.4f}%')
# Out:
# 93.0547%

# %%
imp = pd.DataFrame({'feature': trn.columns, 'importance': clf.feature_importances_})
imp = imp.sort_values('importance').set_index('feature')
imp.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='feature'>

# %%
sub = pd.read_csv(sample_file, index_col=0)
print(sub.shape)
sub.head()
# Out:
# (80000, 1)
#         class
# id
# 320000      0
# 320001      0
# 320002      0
# 320003      0
# 320004      0

# %%
sub[target_col] = p_tst
sub.head()
# Out:
#         class
# id
# 320000    2.0
# 320001    0.0
# 320002    2.0
# 320003    0.0
# 320004    2.0

# %%
sub[target_col].value_counts()
# Out:
# 2.0    41060
# 0.0    29974
# 1.0     8966
# Name: class, dtype: int64

# %%
sub.to_csv(sub_file)
