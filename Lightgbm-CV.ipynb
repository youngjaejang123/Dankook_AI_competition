# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import lightgbm as lgb
from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as np
from pathlib import Path
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
import seaborn as sns
import warnings

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
pd.set_option('max_columns', 100)
pd.set_option("display.precision", 4)
warnings.simplefilter('ignore')

# %%
##학습데이터 로드
#이전 생성한 feature.csv사용
data_dir = Path('../data/dacon-dku')
feature_dir = Path('../build/feature')
val_dir = Path('../build/val')
tst_dir = Path('../build/tst')
sub_dir = Path('../build/sub')

trn_file = data_dir / 'train.csv'
tst_file = data_dir / 'test.csv'
sample_file = data_dir / 'sample_submission.csv'

target_col = 'class'
n_fold = 5
n_class = 3
seed = 42

# %%
algo_name = 'lgbcv'
feature_name = 'feature'
model_name = f'{algo_name}_{feature_name}'

feature_file = feature_dir / f'{feature_name}.csv'
p_val_file = val_dir / f'{model_name}.val.csv'
p_tst_file = tst_dir / f'{model_name}.tst.csv'
sub_file = sub_dir / f'{model_name}.csv'

# %%
df = pd.read_csv(feature_file, index_col=0)
print(df.shape)
df.head()
# Out:
# (400000, 20)
#           z    redshift  dered_u  dered_g  dered_r  dered_i  dered_z  \
# id
# 0   16.9396 -8.1086e-05  23.1243  20.2578  18.9551  17.6321  16.9089
# 1   13.1689  4.5061e-03  14.9664  14.0045  13.4114  13.2363  13.1347
# 2   15.3500  4.7198e-04  16.6076  15.6866  15.4400  15.3217  15.2961
# 3   19.6346  5.8143e-06  25.3536  20.9947  20.0873  19.7947  19.5552
# 4   17.9826 -3.3247e-05  23.7714  20.4338  18.8630  18.1903  17.8759
#
#     nObserve  airmass_u  class  d_dered_u  d_dered_g  d_dered_r  d_dered_i  \
# id
# 0     0.8639     1.1898    0.0    -0.1397    -0.0790    -0.0544    -0.0403
# 1     0.4230     1.2533    1.0    -0.0857    -0.0574    -0.0410    -0.0322
# 2     0.5546     1.0225    0.0    -0.1787    -0.1388    -0.0963    -0.0718
# 3     0.6725     1.2054    0.0    -0.3070    -0.1941    -0.1339    -0.1003
# 4     0.8293     1.1939    0.0    -0.6820    -0.2653    -0.1794    -0.1339
#
#     d_dered_z  d_dered_ig  d_dered_zg  d_dered_rz  d_dered_iz  d_obs_det
# id
# 0     -0.0307     -2.6257     -3.3488      2.0462      0.7232   -17.1361
# 1     -0.0343     -0.7683     -0.8698      0.2767      0.1016    -0.5770
# 2     -0.0540     -0.3649     -0.3905      0.1440      0.0257    -1.4454
# 3     -0.0795     -1.2000     -1.4395      0.5321      0.2395    -2.3275
# 4     -0.1067     -2.2436     -2.5579      0.9871      0.3144   -11.1707

# %%
y = df[target_col].values[:320000]
df.drop(target_col, axis=1, inplace=True)
trn = df.iloc[:320000].values
tst = df.iloc[320000:].values
feature_name = df.columns.tolist()
print(y.shape, trn.shape, tst.shape)
# Out:
# (320000,) (320000, 19) (80000, 19)

# %%
#Stratified K-Fold Cross Validation
cv = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)

# %%
#LightGBM모델 학습
p_val = np.zeros((trn.shape[0], n_class))
p_tst = np.zeros((tst.shape[0], n_class))
for i, (i_trn, i_val) in enumerate(cv.split(trn, y), 1):
    print(f'training model for CV #{i}')
    clf = lgb.LGBMClassifier(objective='multiclass',
                             n_estimators=1000,
                             num_leaves=64,
                             learning_rate=0.1,
                             min_child_samples=10,
                             subsample=.5,
                             subsample_freq=1,
                             colsample_bytree=.8,
                             random_state=seed,
                             n_jobs=-1)
    clf.fit(trn[i_trn], y[i_trn],
            eval_set=[(trn[i_val], y[i_val])],
            eval_metric='multiclass',
            early_stopping_rounds=10)
    
    p_val[i_val, :] = clf.predict_proba(trn[i_val])
    p_tst += clf.predict_proba(tst) / n_fold
# Out:
# training model for CV #1
# [1]	valid_0's multi_logloss: 0.860242
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761507
# [3]	valid_0's multi_logloss: 0.675529
# [4]	valid_0's multi_logloss: 0.60463
# [5]	valid_0's multi_logloss: 0.54672
# [6]	valid_0's multi_logloss: 0.505094
# [7]	valid_0's multi_logloss: 0.467963
# [8]	valid_0's multi_logloss: 0.440034
# [9]	valid_0's multi_logloss: 0.411805
# [10]	valid_0's multi_logloss: 0.382798
# [11]	valid_0's multi_logloss: 0.358656
# [12]	valid_0's multi_logloss: 0.338108
# [13]	valid_0's multi_logloss: 0.319838
# [14]	valid_0's multi_logloss: 0.3033
# [15]	valid_0's multi_logloss: 0.288973
# [16]	valid_0's multi_logloss: 0.276545
# [17]	valid_0's multi_logloss: 0.266206
# [18]	valid_0's multi_logloss: 0.2566
# [19]	valid_0's multi_logloss: 0.247439
# [20]	valid_0's multi_logloss: 0.240376
# [21]	valid_0's multi_logloss: 0.233243
# [22]	valid_0's multi_logloss: 0.226748
# [23]	valid_0's multi_logloss: 0.22086
# [24]	valid_0's multi_logloss: 0.216725
# [25]	valid_0's multi_logloss: 0.212768
# [26]	valid_0's multi_logloss: 0.209205
# [27]	valid_0's multi_logloss: 0.205474
# [28]	valid_0's multi_logloss: 0.201807
# [29]	valid_0's multi_logloss: 0.19845
# [30]	valid_0's multi_logloss: 0.195876
# [31]	valid_0's multi_logloss: 0.193341
# [32]	valid_0's multi_logloss: 0.191317
# [33]	valid_0's multi_logloss: 0.189047
# [34]	valid_0's multi_logloss: 0.187113
# [35]	valid_0's multi_logloss: 0.185149
# [36]	valid_0's multi_logloss: 0.183825
# [37]	valid_0's multi_logloss: 0.182281
# [38]	valid_0's multi_logloss: 0.180893
# [39]	valid_0's multi_logloss: 0.17986
# [40]	valid_0's multi_logloss: 0.178557
# [41]	valid_0's multi_logloss: 0.17741
# [42]	valid_0's multi_logloss: 0.176575
# [43]	valid_0's multi_logloss: 0.175646
# [44]	valid_0's multi_logloss: 0.174782
# [45]	valid_0's multi_logloss: 0.174172
# [46]	valid_0's multi_logloss: 0.173595
# [47]	valid_0's multi_logloss: 0.172983
# [48]	valid_0's multi_logloss: 0.172386
# [49]	valid_0's multi_logloss: 0.171836
# [50]	valid_0's multi_logloss: 0.171449
# [51]	valid_0's multi_logloss: 0.170922
# [52]	valid_0's multi_logloss: 0.170542
# [53]	valid_0's multi_logloss: 0.170031
# [54]	valid_0's multi_logloss: 0.169725
# [55]	valid_0's multi_logloss: 0.169529
# [56]	valid_0's multi_logloss: 0.169121
# [57]	valid_0's multi_logloss: 0.168837
# [58]	valid_0's multi_logloss: 0.168488
# [59]	valid_0's multi_logloss: 0.168222
# [60]	valid_0's multi_logloss: 0.16801
# [61]	valid_0's multi_logloss: 0.167718
# [62]	valid_0's multi_logloss: 0.167406
# [63]	valid_0's multi_logloss: 0.167204
# [64]	valid_0's multi_logloss: 0.166885
# [65]	valid_0's multi_logloss: 0.166732
# [66]	valid_0's multi_logloss: 0.166521
# [67]	valid_0's multi_logloss: 0.166319
# [68]	valid_0's multi_logloss: 0.166182
# [69]	valid_0's multi_logloss: 0.165938
# [70]	valid_0's multi_logloss: 0.165707
# [71]	valid_0's multi_logloss: 0.165972
# [72]	valid_0's multi_logloss: 0.16665
# [73]	valid_0's multi_logloss: 0.167195
# [74]	valid_0's multi_logloss: 0.167138
# [75]	valid_0's multi_logloss: 0.166944
# [76]	valid_0's multi_logloss: 0.16685
# [77]	valid_0's multi_logloss: 0.167608
# [78]	valid_0's multi_logloss: 0.167441
# [79]	valid_0's multi_logloss: 0.16729
# [80]	valid_0's multi_logloss: 0.167146
# Early stopping, best iteration is:
# [70]	valid_0's multi_logloss: 0.165707
# training model for CV #2
# [1]	valid_0's multi_logloss: 0.860914
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761976
# [3]	valid_0's multi_logloss: 0.676416
# [4]	valid_0's multi_logloss: 0.605831
# [5]	valid_0's multi_logloss: 0.54819
# [6]	valid_0's multi_logloss: 0.506725
# [7]	valid_0's multi_logloss: 0.469525
# [8]	valid_0's multi_logloss: 0.441657
# [9]	valid_0's multi_logloss: 0.41376
# [10]	valid_0's multi_logloss: 0.384885
# [11]	valid_0's multi_logloss: 0.360731
# [12]	valid_0's multi_logloss: 0.340161
# [13]	valid_0's multi_logloss: 0.321864
# [14]	valid_0's multi_logloss: 0.304882
# [15]	valid_0's multi_logloss: 0.290546
# [16]	valid_0's multi_logloss: 0.278242
# [17]	valid_0's multi_logloss: 0.267745
# [18]	valid_0's multi_logloss: 0.258036
# [19]	valid_0's multi_logloss: 0.249002
# [20]	valid_0's multi_logloss: 0.241938
# [21]	valid_0's multi_logloss: 0.2346
# [22]	valid_0's multi_logloss: 0.228061
# [23]	valid_0's multi_logloss: 0.222322
# [24]	valid_0's multi_logloss: 0.218154
# [25]	valid_0's multi_logloss: 0.213938
# [26]	valid_0's multi_logloss: 0.210272
# [27]	valid_0's multi_logloss: 0.206212
# [28]	valid_0's multi_logloss: 0.202538
# [29]	valid_0's multi_logloss: 0.199435
# [30]	valid_0's multi_logloss: 0.196885
# [31]	valid_0's multi_logloss: 0.194291
# [32]	valid_0's multi_logloss: 0.19215
# [33]	valid_0's multi_logloss: 0.189855
# [34]	valid_0's multi_logloss: 0.187867
# [35]	valid_0's multi_logloss: 0.185977
# [36]	valid_0's multi_logloss: 0.18447
# [37]	valid_0's multi_logloss: 0.182976
# [38]	valid_0's multi_logloss: 0.181504
# [39]	valid_0's multi_logloss: 0.180406
# [40]	valid_0's multi_logloss: 0.17918
# [41]	valid_0's multi_logloss: 0.178122
# [42]	valid_0's multi_logloss: 0.177254
# [43]	valid_0's multi_logloss: 0.176326
# [44]	valid_0's multi_logloss: 0.1755
# [45]	valid_0's multi_logloss: 0.174818
# [46]	valid_0's multi_logloss: 0.17413
# [47]	valid_0's multi_logloss: 0.173444
# [48]	valid_0's multi_logloss: 0.172851
# [49]	valid_0's multi_logloss: 0.17233
# [50]	valid_0's multi_logloss: 0.171927
# [51]	valid_0's multi_logloss: 0.171426
# [52]	valid_0's multi_logloss: 0.170945
# [53]	valid_0's multi_logloss: 0.170507
# [54]	valid_0's multi_logloss: 0.170244
# [55]	valid_0's multi_logloss: 0.17002
# [56]	valid_0's multi_logloss: 0.169682
# [57]	valid_0's multi_logloss: 0.169321
# [58]	valid_0's multi_logloss: 0.169003
# [59]	valid_0's multi_logloss: 0.168806
# [60]	valid_0's multi_logloss: 0.1686
# [61]	valid_0's multi_logloss: 0.1683
# [62]	valid_0's multi_logloss: 0.168037
# [63]	valid_0's multi_logloss: 0.167798
# [64]	valid_0's multi_logloss: 0.167488
# [65]	valid_0's multi_logloss: 0.167326
# [66]	valid_0's multi_logloss: 0.167099
# [67]	valid_0's multi_logloss: 0.166995
# [68]	valid_0's multi_logloss: 0.167208
# [69]	valid_0's multi_logloss: 0.166743
# [70]	valid_0's multi_logloss: 0.166474
# [71]	valid_0's multi_logloss: 0.166363
# [72]	valid_0's multi_logloss: 0.166218
# [73]	valid_0's multi_logloss: 0.166249
# [74]	valid_0's multi_logloss: 0.166116
# [75]	valid_0's multi_logloss: 0.166021
# [76]	valid_0's multi_logloss: 0.165893
# [77]	valid_0's multi_logloss: 0.165781
# [78]	valid_0's multi_logloss: 0.165907
# [79]	valid_0's multi_logloss: 0.165809
# [80]	valid_0's multi_logloss: 0.165747
# [81]	valid_0's multi_logloss: 0.165613
# [82]	valid_0's multi_logloss: 0.165535
# [83]	valid_0's multi_logloss: 0.165485
# [84]	valid_0's multi_logloss: 0.165383
# [85]	valid_0's multi_logloss: 0.165282
# [86]	valid_0's multi_logloss: 0.1652
# [87]	valid_0's multi_logloss: 0.165123
# [88]	valid_0's multi_logloss: 0.165018
# [89]	valid_0's multi_logloss: 0.164921
# [90]	valid_0's multi_logloss: 0.164881
# [91]	valid_0's multi_logloss: 0.164896
# [92]	valid_0's multi_logloss: 0.164831
# [93]	valid_0's multi_logloss: 0.164713
# [94]	valid_0's multi_logloss: 0.164643
# [95]	valid_0's multi_logloss: 0.164554
# [96]	valid_0's multi_logloss: 0.164603
# [97]	valid_0's multi_logloss: 0.164509
# [98]	valid_0's multi_logloss: 0.164457
# [99]	valid_0's multi_logloss: 0.164379
# [100]	valid_0's multi_logloss: 0.164347
# [101]	valid_0's multi_logloss: 0.164289
# [102]	valid_0's multi_logloss: 0.164244
# [103]	valid_0's multi_logloss: 0.164241
# [104]	valid_0's multi_logloss: 0.164165
# [105]	valid_0's multi_logloss: 0.164153
# [106]	valid_0's multi_logloss: 0.164105
# [107]	valid_0's multi_logloss: 0.164099
# [108]	valid_0's multi_logloss: 0.164081
# [109]	valid_0's multi_logloss: 0.164074
# [110]	valid_0's multi_logloss: 0.164033
# [111]	valid_0's multi_logloss: 0.164027
# [112]	valid_0's multi_logloss: 0.16404
# [113]	valid_0's multi_logloss: 0.164018
# [114]	valid_0's multi_logloss: 0.164035
# [115]	valid_0's multi_logloss: 0.163979
# [116]	valid_0's multi_logloss: 0.163963
# [117]	valid_0's multi_logloss: 0.16391
# [118]	valid_0's multi_logloss: 0.163904
# [119]	valid_0's multi_logloss: 0.16382
# [120]	valid_0's multi_logloss: 0.163812
# [121]	valid_0's multi_logloss: 0.163808
# [122]	valid_0's multi_logloss: 0.163741
# [123]	valid_0's multi_logloss: 0.163757
# [124]	valid_0's multi_logloss: 0.16372
# [125]	valid_0's multi_logloss: 0.163711
# [126]	valid_0's multi_logloss: 0.163674
# [127]	valid_0's multi_logloss: 0.163637
# [128]	valid_0's multi_logloss: 0.163596
# [129]	valid_0's multi_logloss: 0.163586
# [130]	valid_0's multi_logloss: 0.163587
# [131]	valid_0's multi_logloss: 0.163579
# [132]	valid_0's multi_logloss: 0.163586
# [133]	valid_0's multi_logloss: 0.163554
# [134]	valid_0's multi_logloss: 0.163577
# [135]	valid_0's multi_logloss: 0.16357
# [136]	valid_0's multi_logloss: 0.163564
# [137]	valid_0's multi_logloss: 0.163522
# [138]	valid_0's multi_logloss: 0.163518
# [139]	valid_0's multi_logloss: 0.163534
# [140]	valid_0's multi_logloss: 0.163498
# [141]	valid_0's multi_logloss: 0.163388
# [142]	valid_0's multi_logloss: 0.163368
# [143]	valid_0's multi_logloss: 0.163339
# [144]	valid_0's multi_logloss: 0.16333
# [145]	valid_0's multi_logloss: 0.163281
# [146]	valid_0's multi_logloss: 0.163315
# [147]	valid_0's multi_logloss: 0.163317
# [148]	valid_0's multi_logloss: 0.163249
# [149]	valid_0's multi_logloss: 0.163204
# [150]	valid_0's multi_logloss: 0.163209
# [151]	valid_0's multi_logloss: 0.16321
# [152]	valid_0's multi_logloss: 0.163191
# [153]	valid_0's multi_logloss: 0.163173
# [154]	valid_0's multi_logloss: 0.163144
# [155]	valid_0's multi_logloss: 0.163125
# [156]	valid_0's multi_logloss: 0.163116
# [157]	valid_0's multi_logloss: 0.163137
# [158]	valid_0's multi_logloss: 0.163115
# [159]	valid_0's multi_logloss: 0.163119
# [160]	valid_0's multi_logloss: 0.163118
# [161]	valid_0's multi_logloss: 0.163171
# [162]	valid_0's multi_logloss: 0.163139
# [163]	valid_0's multi_logloss: 0.163174
# [164]	valid_0's multi_logloss: 0.163154
# [165]	valid_0's multi_logloss: 0.16317
# [166]	valid_0's multi_logloss: 0.163149
# [167]	valid_0's multi_logloss: 0.16311
# [168]	valid_0's multi_logloss: 0.163106
# [169]	valid_0's multi_logloss: 0.163067
# [170]	valid_0's multi_logloss: 0.16305
# [171]	valid_0's multi_logloss: 0.163074
# [172]	valid_0's multi_logloss: 0.163093
# [173]	valid_0's multi_logloss: 0.163119
# [174]	valid_0's multi_logloss: 0.163061
# [175]	valid_0's multi_logloss: 0.163034
# [176]	valid_0's multi_logloss: 0.163044
# [177]	valid_0's multi_logloss: 0.163027
# [178]	valid_0's multi_logloss: 0.162986
# [179]	valid_0's multi_logloss: 0.162953
# [180]	valid_0's multi_logloss: 0.162952
# [181]	valid_0's multi_logloss: 0.162928
# [182]	valid_0's multi_logloss: 0.162949
# [183]	valid_0's multi_logloss: 0.162958
# [184]	valid_0's multi_logloss: 0.162925
# [185]	valid_0's multi_logloss: 0.162956
# [186]	valid_0's multi_logloss: 0.162993
# [187]	valid_0's multi_logloss: 0.162987
# [188]	valid_0's multi_logloss: 0.162979
# [189]	valid_0's multi_logloss: 0.162952
# [190]	valid_0's multi_logloss: 0.162951
# [191]	valid_0's multi_logloss: 0.162969
# [192]	valid_0's multi_logloss: 0.162953
# [193]	valid_0's multi_logloss: 0.162958
# [194]	valid_0's multi_logloss: 0.16297
# Early stopping, best iteration is:
# [184]	valid_0's multi_logloss: 0.162925
# training model for CV #3
# [1]	valid_0's multi_logloss: 0.860646
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761943
# [3]	valid_0's multi_logloss: 0.676158
# [4]	valid_0's multi_logloss: 0.605962
# [5]	valid_0's multi_logloss: 0.548442
# [6]	valid_0's multi_logloss: 0.506519
# [7]	valid_0's multi_logloss: 0.469401
# [8]	valid_0's multi_logloss: 0.441633
# [9]	valid_0's multi_logloss: 0.413725
# [10]	valid_0's multi_logloss: 0.384951
# [11]	valid_0's multi_logloss: 0.361161
# [12]	valid_0's multi_logloss: 0.340537
# [13]	valid_0's multi_logloss: 0.32236
# [14]	valid_0's multi_logloss: 0.305631
# [15]	valid_0's multi_logloss: 0.291424
# [16]	valid_0's multi_logloss: 0.279103
# [17]	valid_0's multi_logloss: 0.26872
# [18]	valid_0's multi_logloss: 0.259098
# [19]	valid_0's multi_logloss: 0.249735
# [20]	valid_0's multi_logloss: 0.242705
# [21]	valid_0's multi_logloss: 0.23531
# [22]	valid_0's multi_logloss: 0.229076
# [23]	valid_0's multi_logloss: 0.22324
# [24]	valid_0's multi_logloss: 0.219205
# [25]	valid_0's multi_logloss: 0.214942
# [26]	valid_0's multi_logloss: 0.211335
# [27]	valid_0's multi_logloss: 0.20749
# [28]	valid_0's multi_logloss: 0.203816
# [29]	valid_0's multi_logloss: 0.200626
# [30]	valid_0's multi_logloss: 0.197981
# [31]	valid_0's multi_logloss: 0.19533
# [32]	valid_0's multi_logloss: 0.193335
# [33]	valid_0's multi_logloss: 0.191131
# [34]	valid_0's multi_logloss: 0.189025
# [35]	valid_0's multi_logloss: 0.187099
# [36]	valid_0's multi_logloss: 0.185718
# [37]	valid_0's multi_logloss: 0.184218
# [38]	valid_0's multi_logloss: 0.182809
# [39]	valid_0's multi_logloss: 0.181733
# [40]	valid_0's multi_logloss: 0.180499
# [41]	valid_0's multi_logloss: 0.179361
# [42]	valid_0's multi_logloss: 0.178426
# [43]	valid_0's multi_logloss: 0.177522
# [44]	valid_0's multi_logloss: 0.17661
# [45]	valid_0's multi_logloss: 0.175963
# [46]	valid_0's multi_logloss: 0.175368
# [47]	valid_0's multi_logloss: 0.174731
# [48]	valid_0's multi_logloss: 0.17413
# [49]	valid_0's multi_logloss: 0.17354
# [50]	valid_0's multi_logloss: 0.173044
# [51]	valid_0's multi_logloss: 0.172575
# [52]	valid_0's multi_logloss: 0.172211
# [53]	valid_0's multi_logloss: 0.171717
# [54]	valid_0's multi_logloss: 0.171474
# [55]	valid_0's multi_logloss: 0.17125
# [56]	valid_0's multi_logloss: 0.170856
# [57]	valid_0's multi_logloss: 0.170508
# [58]	valid_0's multi_logloss: 0.170242
# [59]	valid_0's multi_logloss: 0.170044
# [60]	valid_0's multi_logloss: 0.16976
# [61]	valid_0's multi_logloss: 0.169489
# [62]	valid_0's multi_logloss: 0.169302
# [63]	valid_0's multi_logloss: 0.16906
# [64]	valid_0's multi_logloss: 0.168713
# [65]	valid_0's multi_logloss: 0.168539
# [66]	valid_0's multi_logloss: 0.168265
# [67]	valid_0's multi_logloss: 0.168123
# [68]	valid_0's multi_logloss: 0.167943
# [69]	valid_0's multi_logloss: 0.1677
# [70]	valid_0's multi_logloss: 0.167607
# [71]	valid_0's multi_logloss: 0.167603
# [72]	valid_0's multi_logloss: 0.167446
# [73]	valid_0's multi_logloss: 0.16732
# [74]	valid_0's multi_logloss: 0.167266
# [75]	valid_0's multi_logloss: 0.16718
# [76]	valid_0's multi_logloss: 0.166971
# [77]	valid_0's multi_logloss: 0.166887
# [78]	valid_0's multi_logloss: 0.166708
# [79]	valid_0's multi_logloss: 0.166554
# [80]	valid_0's multi_logloss: 0.166493
# [81]	valid_0's multi_logloss: 0.16636
# [82]	valid_0's multi_logloss: 0.166313
# [83]	valid_0's multi_logloss: 0.166132
# [84]	valid_0's multi_logloss: 0.166099
# [85]	valid_0's multi_logloss: 0.166015
# [86]	valid_0's multi_logloss: 0.16592
# [87]	valid_0's multi_logloss: 0.165847
# [88]	valid_0's multi_logloss: 0.165774
# [89]	valid_0's multi_logloss: 0.165705
# [90]	valid_0's multi_logloss: 0.165655
# [91]	valid_0's multi_logloss: 0.165581
# [92]	valid_0's multi_logloss: 0.165574
# [93]	valid_0's multi_logloss: 0.165456
# [94]	valid_0's multi_logloss: 0.165351
# [95]	valid_0's multi_logloss: 0.165304
# [96]	valid_0's multi_logloss: 0.165234
# [97]	valid_0's multi_logloss: 0.165213
# [98]	valid_0's multi_logloss: 0.165147
# [99]	valid_0's multi_logloss: 0.165049
# [100]	valid_0's multi_logloss: 0.165024
# [101]	valid_0's multi_logloss: 0.164984
# [102]	valid_0's multi_logloss: 0.164943
# [103]	valid_0's multi_logloss: 0.16488
# [104]	valid_0's multi_logloss: 0.16489
# [105]	valid_0's multi_logloss: 0.164815
# [106]	valid_0's multi_logloss: 0.164719
# [107]	valid_0's multi_logloss: 0.164705
# [108]	valid_0's multi_logloss: 0.164683
# [109]	valid_0's multi_logloss: 0.164624
# [110]	valid_0's multi_logloss: 0.164612
# [111]	valid_0's multi_logloss: 0.164634
# [112]	valid_0's multi_logloss: 0.164592
# [113]	valid_0's multi_logloss: 0.164543
# [114]	valid_0's multi_logloss: 0.164572
# [115]	valid_0's multi_logloss: 0.164548
# [116]	valid_0's multi_logloss: 0.164534
# [117]	valid_0's multi_logloss: 0.164436
# [118]	valid_0's multi_logloss: 0.164426
# [119]	valid_0's multi_logloss: 0.164416
# [120]	valid_0's multi_logloss: 0.164433
# [121]	valid_0's multi_logloss: 0.164369
# [122]	valid_0's multi_logloss: 0.164336
# [123]	valid_0's multi_logloss: 0.16427
# [124]	valid_0's multi_logloss: 0.16427
# [125]	valid_0's multi_logloss: 0.164242
# [126]	valid_0's multi_logloss: 0.16429
# [127]	valid_0's multi_logloss: 0.164256
# [128]	valid_0's multi_logloss: 0.164275
# [129]	valid_0's multi_logloss: 0.164275
# [130]	valid_0's multi_logloss: 0.164279
# [131]	valid_0's multi_logloss: 0.16426
# [132]	valid_0's multi_logloss: 0.164326
# [133]	valid_0's multi_logloss: 0.164281
# [134]	valid_0's multi_logloss: 0.164311
# [135]	valid_0's multi_logloss: 0.164287
# Early stopping, best iteration is:
# [125]	valid_0's multi_logloss: 0.164242
# training model for CV #4
# [1]	valid_0's multi_logloss: 0.860231
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761193
# [3]	valid_0's multi_logloss: 0.675561
# [4]	valid_0's multi_logloss: 0.605093
# [5]	valid_0's multi_logloss: 0.54734
# [6]	valid_0's multi_logloss: 0.505848
# [7]	valid_0's multi_logloss: 0.468939
# [8]	valid_0's multi_logloss: 0.441277
# [9]	valid_0's multi_logloss: 0.413237
# [10]	valid_0's multi_logloss: 0.384687
# [11]	valid_0's multi_logloss: 0.360488
# [12]	valid_0's multi_logloss: 0.33983
# [13]	valid_0's multi_logloss: 0.321693
# [14]	valid_0's multi_logloss: 0.305311
# [15]	valid_0's multi_logloss: 0.29081
# [16]	valid_0's multi_logloss: 0.278536
# [17]	valid_0's multi_logloss: 0.268098
# [18]	valid_0's multi_logloss: 0.258536
# [19]	valid_0's multi_logloss: 0.249141
# [20]	valid_0's multi_logloss: 0.242371
# [21]	valid_0's multi_logloss: 0.234896
# [22]	valid_0's multi_logloss: 0.228369
# [23]	valid_0's multi_logloss: 0.222493
# [24]	valid_0's multi_logloss: 0.218362
# [25]	valid_0's multi_logloss: 0.214556
# [26]	valid_0's multi_logloss: 0.211001
# [27]	valid_0's multi_logloss: 0.207315
# [28]	valid_0's multi_logloss: 0.203648
# [29]	valid_0's multi_logloss: 0.200364
# [30]	valid_0's multi_logloss: 0.197732
# [31]	valid_0's multi_logloss: 0.195067
# [32]	valid_0's multi_logloss: 0.193008
# [33]	valid_0's multi_logloss: 0.190849
# [34]	valid_0's multi_logloss: 0.188804
# [35]	valid_0's multi_logloss: 0.186885
# [36]	valid_0's multi_logloss: 0.18565
# [37]	valid_0's multi_logloss: 0.184101
# [38]	valid_0's multi_logloss: 0.182619
# [39]	valid_0's multi_logloss: 0.181476
# [40]	valid_0's multi_logloss: 0.180265
# [41]	valid_0's multi_logloss: 0.179186
# [42]	valid_0's multi_logloss: 0.178384
# [43]	valid_0's multi_logloss: 0.177439
# [44]	valid_0's multi_logloss: 0.176652
# [45]	valid_0's multi_logloss: 0.176025
# [46]	valid_0's multi_logloss: 0.17543
# [47]	valid_0's multi_logloss: 0.174801
# [48]	valid_0's multi_logloss: 0.174167
# [49]	valid_0's multi_logloss: 0.173623
# [50]	valid_0's multi_logloss: 0.173107
# [51]	valid_0's multi_logloss: 0.172601
# [52]	valid_0's multi_logloss: 0.172224
# [53]	valid_0's multi_logloss: 0.171745
# [54]	valid_0's multi_logloss: 0.171477
# [55]	valid_0's multi_logloss: 0.171272
# [56]	valid_0's multi_logloss: 0.171026
# [57]	valid_0's multi_logloss: 0.170646
# [58]	valid_0's multi_logloss: 0.170294
# [59]	valid_0's multi_logloss: 0.170004
# [60]	valid_0's multi_logloss: 0.169735
# [61]	valid_0's multi_logloss: 0.169431
# [62]	valid_0's multi_logloss: 0.16927
# [63]	valid_0's multi_logloss: 0.169052
# [64]	valid_0's multi_logloss: 0.168832
# [65]	valid_0's multi_logloss: 0.168609
# [66]	valid_0's multi_logloss: 0.168328
# [67]	valid_0's multi_logloss: 0.168165
# [68]	valid_0's multi_logloss: 0.167998
# [69]	valid_0's multi_logloss: 0.167814
# [70]	valid_0's multi_logloss: 0.167668
# [71]	valid_0's multi_logloss: 0.167593
# [72]	valid_0's multi_logloss: 0.167482
# [73]	valid_0's multi_logloss: 0.167382
# [74]	valid_0's multi_logloss: 0.167267
# [75]	valid_0's multi_logloss: 0.167178
# [76]	valid_0's multi_logloss: 0.167066
# [77]	valid_0's multi_logloss: 0.167411
# [78]	valid_0's multi_logloss: 0.168532
# [79]	valid_0's multi_logloss: 0.167811
# [80]	valid_0's multi_logloss: 0.167713
# [81]	valid_0's multi_logloss: 0.167581
# [82]	valid_0's multi_logloss: 0.167403
# [83]	valid_0's multi_logloss: 0.167257
# [84]	valid_0's multi_logloss: 0.167153
# [85]	valid_0's multi_logloss: 0.167136
# [86]	valid_0's multi_logloss: 0.167043
# [87]	valid_0's multi_logloss: 0.166924
# [88]	valid_0's multi_logloss: 0.166912
# [89]	valid_0's multi_logloss: 0.166813
# [90]	valid_0's multi_logloss: 0.16671
# [91]	valid_0's multi_logloss: 0.166621
# [92]	valid_0's multi_logloss: 0.166577
# [93]	valid_0's multi_logloss: 0.166505
# [94]	valid_0's multi_logloss: 0.166445
# [95]	valid_0's multi_logloss: 0.169089
# [96]	valid_0's multi_logloss: 0.166837
# [97]	valid_0's multi_logloss: 0.166946
# [98]	valid_0's multi_logloss: 0.166667
# [99]	valid_0's multi_logloss: 0.166615
# [100]	valid_0's multi_logloss: 0.166548
# [101]	valid_0's multi_logloss: 0.169691
# [102]	valid_0's multi_logloss: 0.169804
# [103]	valid_0's multi_logloss: 0.169752
# [104]	valid_0's multi_logloss: 0.172526
# Early stopping, best iteration is:
# [94]	valid_0's multi_logloss: 0.166445
# training model for CV #5
# [1]	valid_0's multi_logloss: 0.860564
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's multi_logloss: 0.761593
# [3]	valid_0's multi_logloss: 0.676029
# [4]	valid_0's multi_logloss: 0.605812
# [5]	valid_0's multi_logloss: 0.54802
# [6]	valid_0's multi_logloss: 0.506257
# [7]	valid_0's multi_logloss: 0.469148
# [8]	valid_0's multi_logloss: 0.441391
# [9]	valid_0's multi_logloss: 0.413011
# [10]	valid_0's multi_logloss: 0.384288
# [11]	valid_0's multi_logloss: 0.360003
# [12]	valid_0's multi_logloss: 0.33936
# [13]	valid_0's multi_logloss: 0.321144
# [14]	valid_0's multi_logloss: 0.304473
# [15]	valid_0's multi_logloss: 0.29016
# [16]	valid_0's multi_logloss: 0.278118
# [17]	valid_0's multi_logloss: 0.267649
# [18]	valid_0's multi_logloss: 0.257858
# [19]	valid_0's multi_logloss: 0.248563
# [20]	valid_0's multi_logloss: 0.241644
# [21]	valid_0's multi_logloss: 0.234469
# [22]	valid_0's multi_logloss: 0.227996
# [23]	valid_0's multi_logloss: 0.222193
# [24]	valid_0's multi_logloss: 0.217865
# [25]	valid_0's multi_logloss: 0.213579
# [26]	valid_0's multi_logloss: 0.210003
# [27]	valid_0's multi_logloss: 0.206215
# [28]	valid_0's multi_logloss: 0.202618
# [29]	valid_0's multi_logloss: 0.199322
# [30]	valid_0's multi_logloss: 0.19678
# [31]	valid_0's multi_logloss: 0.194052
# [32]	valid_0's multi_logloss: 0.191948
# [33]	valid_0's multi_logloss: 0.189717
# [34]	valid_0's multi_logloss: 0.187631
# [35]	valid_0's multi_logloss: 0.185857
# [36]	valid_0's multi_logloss: 0.184478
# [37]	valid_0's multi_logloss: 0.183028
# [38]	valid_0's multi_logloss: 0.181576
# [39]	valid_0's multi_logloss: 0.180632
# [40]	valid_0's multi_logloss: 0.179454
# [41]	valid_0's multi_logloss: 0.17836
# [42]	valid_0's multi_logloss: 0.17739
# [43]	valid_0's multi_logloss: 0.17652
# [44]	valid_0's multi_logloss: 0.175654
# [45]	valid_0's multi_logloss: 0.175018
# [46]	valid_0's multi_logloss: 0.174513
# [47]	valid_0's multi_logloss: 0.173775
# [48]	valid_0's multi_logloss: 0.173157
# [49]	valid_0's multi_logloss: 0.172531
# [50]	valid_0's multi_logloss: 0.172034
# [51]	valid_0's multi_logloss: 0.171491
# [52]	valid_0's multi_logloss: 0.171089
# [53]	valid_0's multi_logloss: 0.17064
# [54]	valid_0's multi_logloss: 0.170364
# [55]	valid_0's multi_logloss: 0.170145
# [56]	valid_0's multi_logloss: 0.169851
# [57]	valid_0's multi_logloss: 0.169438
# [58]	valid_0's multi_logloss: 0.169172
# [59]	valid_0's multi_logloss: 0.168809
# [60]	valid_0's multi_logloss: 0.168582
# [61]	valid_0's multi_logloss: 0.168228
# [62]	valid_0's multi_logloss: 0.167984
# [63]	valid_0's multi_logloss: 0.167761
# [64]	valid_0's multi_logloss: 0.167625
# [65]	valid_0's multi_logloss: 0.167443
# [66]	valid_0's multi_logloss: 0.167223
# [67]	valid_0's multi_logloss: 0.16702
# [68]	valid_0's multi_logloss: 0.166787
# [69]	valid_0's multi_logloss: 0.166554
# [70]	valid_0's multi_logloss: 0.166415
# [71]	valid_0's multi_logloss: 0.16626
# [72]	valid_0's multi_logloss: 0.166187
# [73]	valid_0's multi_logloss: 0.16617
# [74]	valid_0's multi_logloss: 0.166134
# [75]	valid_0's multi_logloss: 0.166043
# [76]	valid_0's multi_logloss: 0.16594
# [77]	valid_0's multi_logloss: 0.165836
# [78]	valid_0's multi_logloss: 0.165726
# [79]	valid_0's multi_logloss: 0.165544
# [80]	valid_0's multi_logloss: 0.165476
# [81]	valid_0's multi_logloss: 0.16536
# [82]	valid_0's multi_logloss: 0.165287
# [83]	valid_0's multi_logloss: 0.165187
# [84]	valid_0's multi_logloss: 0.165078
# [85]	valid_0's multi_logloss: 0.164996
# [86]	valid_0's multi_logloss: 0.164904
# [87]	valid_0's multi_logloss: 0.165651
# [88]	valid_0's multi_logloss: 0.164713
# [89]	valid_0's multi_logloss: 0.166788
# [90]	valid_0's multi_logloss: 0.166836
# [91]	valid_0's multi_logloss: 0.168696
# [92]	valid_0's multi_logloss: 0.167865
# [93]	valid_0's multi_logloss: 0.168243
# [94]	valid_0's multi_logloss: 0.168378
# [95]	valid_0's multi_logloss: 0.170737
# [96]	valid_0's multi_logloss: 0.172403
# [97]	valid_0's multi_logloss: 0.174943
# [98]	valid_0's multi_logloss: 0.173386
# Early stopping, best iteration is:
# [88]	valid_0's multi_logloss: 0.164713

# %%
print(f'{accuracy_score(y, np.argmax(p_val, axis=1)) * 100:.4f}%')
# Out:
# 93.0856%

# %%
print(p_val.shape, p_tst.shape)
# Out:
# (320000, 3) (80000, 3)

# %%
np.savetxt(p_val_file, p_val, fmt='%.6f', delimiter=',')
np.savetxt(p_tst_file, p_tst, fmt='%.6f', delimiter=',')

# %%
#피처 중요도 시각화
imp = pd.DataFrame({'feature': df.columns, 'importance': clf.feature_importances_})
imp = imp.sort_values('importance').set_index('feature')
imp.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='feature'>

# %%
#제출 파일 생성
sub = pd.read_csv(sample_file, index_col=0)
print(sub.shape)
sub.head()
# Out:
# (80000, 1)
#         class
# id
# 320000      0
# 320001      0
# 320002      0
# 320003      0
# 320004      0

# %%
sub[target_col] = np.argmax(p_tst, axis=1)
sub.head()
# Out:
#         class
# id
# 320000      2
# 320001      0
# 320002      2
# 320003      0
# 320004      2

# %%
sub[target_col].value_counts()
# Out:
# 2    41194
# 0    29966
# 1     8840
# Name: class, dtype: int64

# %%
sub.to_csv(sub_file)
